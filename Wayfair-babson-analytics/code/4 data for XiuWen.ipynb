# %%
import pandas as pd

# %%
data = pd.read_csv('../data/2cluster_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  level_0  index VisitDate       UniqueVisitID  \
# 0           0        0      0  7/1/2017    2014237601010030
# 1           3        3      3  7/1/2017    6875972920873110
# 2          12       12     12  7/1/2017   43601232830137300
# 3          23       23     23  7/1/2017   92348156703921600
# 4          27       27     27  7/1/2017  108128856350380000
#
#                   VisitorGroup PlatformUsed       VisitSource BrowserName  \
# 0  Prior Visitor with Purchase          Web     ThirdPartyAds      Chrome
# 1  Prior Visitor with Purchase        Phone  EmailFromWayfair      Safari
# 2                Prior Visitor          Web         WebSearch      Safari
# 3  Prior Visitor with Purchase        Phone  EmailFromWayfair      Safari
# 4  Prior Visitor with Purchase          Web     ThirdPartyAds      Chrome
#
#      OSName  ... ViewedProductInVisit ViewedSaleInVisit TotalPageViews  \
# 0  Mac OS X  ...                    0                 0              1
# ...

# %%
data = data.drop(['Unnamed: 0','level_0','index'],axis=1)

# %%
data.head()
# Out:
#   VisitDate       UniqueVisitID                 VisitorGroup PlatformUsed  \
# 0  7/1/2017    2014237601010030  Prior Visitor with Purchase          Web
# 1  7/1/2017    6875972920873110  Prior Visitor with Purchase        Phone
# 2  7/1/2017   43601232830137300                Prior Visitor          Web
# 3  7/1/2017   92348156703921600  Prior Visitor with Purchase        Phone
# 4  7/1/2017  108128856350380000  Prior Visitor with Purchase          Web
#
#         VisitSource BrowserName    OSName       State   Gender IncomeRange  \
# 0     ThirdPartyAds      Chrome  Mac OS X     eastern   Female   100to250k
# 1  EmailFromWayfair      Safari       iOS  west_coast   Female   100to250k
# 2         WebSearch      Safari       iOS  west_coast   Female   100to250k
# 3  EmailFromWayfair      Safari       iOS     eastern   Female    50to100k
# 4     ThirdPartyAds      Chrome   Windows     eastern  Unknown   100to250k
#
# ...

# %%
data = data.query('VisitorGroup == "Prior Visitor with Purchase"')

# %%
data.shape
# Out:
# (344735, 20)

# %%
data.to_csv('../data/dataforXiuWen1.csv')
