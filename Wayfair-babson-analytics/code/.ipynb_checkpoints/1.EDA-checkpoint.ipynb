# %%
import pandas as pd
# pd.options.display.max_rows = None

# %%
data = pd.read_csv('data/Wayfair-Babson_HackathonData 2019.csv')

# %%
data

# %% [raw]
# Column Title  Definition
# VisitDate     Date of Visit.
# UniqueVisitID ID of unique visit by a visitor.
# VisitorGrou   Visitor's past history with Wayfair (if any).
# PlatformUsed  Platform from which visitor accessed site.
# VisitSource   Channel from which visitor landed on site.
# BrowserName   Browser from which visitor accessed site.
# OSName        Operating System from which visitor accessed site.
# State         State in which user visited site (if available).
# Gender        Gender of user (if available).
# IncomeRange   Income range of user (if available).
# ViewedProductInVisit
#               Whether or not visitor viewed a product during visit (1=Yes, 0=No).
# ViewedSaleInVisit
#               Whether or not visitor viewed a sale page during visit (1=Yes, 0=No).
# TotalPageViews
#               Total # pages viewed during visit.
# PlacedSearch
#               Whether or not visitor placed a search during visit (1=Yes, 0=No).
# SecondsOnSite
#               Total time spent on site during visit.
# ClickedBanner
#               Whether or not visitor clicked a banner on the website (1=Yes, 0=No).
# AddedToBasket
#              Whether or not visitor added any product to basket during visit (1=Yes, 0=No).
# Purchased
#              Whether or not visitor purchased any product to basket during visit (1=Yes, 0=No).

# %%
data[data.IncomeRange.notnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383272 entries, 0 to 992975
# Data columns (total 18 columns):
# VisitDate               383272 non-null object
# UniqueVisitID           383272 non-null int64
# VisitorGroup            383272 non-null object
# PlatformUsed            383272 non-null object
# VisitSource             383272 non-null object
# BrowserName             383272 non-null object
# OSName                  383272 non-null object
# State                   381111 non-null object
# Gender                  383272 non-null object
# IncomeRange             383272 non-null object
# ViewedProductInVisit    383272 non-null int64
# ViewedSaleInVisit       383272 non-null int64
# TotalPageViews          383272 non-null int64
# PlacedSearch            383272 non-null int64
# SecondsOnSite           383272 non-null int64
# ClickedBanner           383272 non-null int64
# AddedToBasket           383272 non-null int64
# Purchased               383272 non-null int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992977 entries, 0 to 992976
# Data columns (total 18 columns):
# VisitDate               992977 non-null object
# UniqueVisitID           992977 non-null int64
# VisitorGroup            992977 non-null object
# PlatformUsed            992977 non-null object
# VisitSource             992977 non-null object
# BrowserName             992977 non-null object
# OSName                  992977 non-null object
# State                   408261 non-null object
# Gender                  639596 non-null object
# IncomeRange             383272 non-null object
# ViewedProductInVisit    992977 non-null int64
# ViewedSaleInVisit       992977 non-null int64
# TotalPageViews          992977 non-null int64
# PlacedSearch            992977 non-null int64
# SecondsOnSite           992977 non-null int64
# ClickedBanner           992977 non-null int64
# AddedToBasket           992977 non-null int64
# Purchased               992977 non-null int64
# ...

# %%
data.describe()
# Out:
#        UniqueVisitID  ViewedProductInVisit  ViewedSaleInVisit  TotalPageViews  \
# count   9.929770e+05         992977.000000      992977.000000   992977.000000
# mean    4.608987e+18              0.509052           0.139695       13.975567
# std     2.661529e+18              0.499918           0.346671       23.037259
# min     1.328642e+13              0.000000           0.000000        1.000000
# 25%     2.304611e+18              0.000000           0.000000        3.000000
# 50%     4.607863e+18              1.000000           0.000000        7.000000
# 75%     6.913873e+18              1.000000           0.000000       16.000000
# max     9.223330e+18              1.000000           1.000000     1217.000000
#
#         PlacedSearch  SecondsOnSite  ClickedBanner  AddedToBasket  \
# count  992977.000000  992977.000000  992977.000000  992977.000000
# mean        0.366073    1436.925027       0.046510       0.106376
# std         0.481730    3216.872703       0.210586       0.308319
# ...

# %%
data.UniqueVisitID.unique()

# %%
datanotnull = data[data.notnull()]

# %%
datanotnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992977 entries, 0 to 992976
# Data columns (total 18 columns):
# VisitDate               992977 non-null object
# UniqueVisitID           992977 non-null int64
# VisitorGroup            992977 non-null object
# PlatformUsed            992977 non-null object
# VisitSource             992977 non-null object
# BrowserName             992977 non-null object
# OSName                  992977 non-null object
# State                   408261 non-null object
# Gender                  639596 non-null object
# IncomeRange             383272 non-null object
# ViewedProductInVisit    992977 non-null int64
# ViewedSaleInVisit       992977 non-null int64
# TotalPageViews          992977 non-null int64
# PlacedSearch            992977 non-null int64
# SecondsOnSite           992977 non-null int64
# ClickedBanner           992977 non-null int64
# AddedToBasket           992977 non-null int64
# Purchased               992977 non-null int64
# ...

# %%
# Out:
# VisitDate               True
# UniqueVisitID           True
# VisitorGroup            True
# PlatformUsed            True
# VisitSource             True
# BrowserName             True
# OSName                  True
# State                   True
# Gender                  True
# IncomeRange             True
# ViewedProductInVisit    True
# ViewedSaleInVisit       True
# TotalPageViews          True
# PlacedSearch            True
# SecondsOnSite           True
# ClickedBanner           True
# AddedToBasket           True
# Purchased               True
# dtype: bool

# %%
data.query('UniqueVisitID == 2909699474086000')
# Out:
#   VisitDate     UniqueVisitID VisitorGroup PlatformUsed VisitSource  \
# 1  7/1/2017  2909699474086000  New Visitor        Phone   WebSearch
#
#   BrowserName OSName State Gender IncomeRange  ViewedProductInVisit  \
# 1      Safari    iOS   NaN    NaN         NaN                     1
#
#    ViewedSaleInVisit  TotalPageViews  PlacedSearch  SecondsOnSite  \
# 1                  0               9             0            230
#
#    ClickedBanner  AddedToBasket  Purchased
# 1              0              0          0

# %%
datagroupbyID = data.groupby(data['UniqueVisitID'])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-bb8534982d88> in <module>
# ----> 1 data.groupby(data['UniqueVisitID']).count_value()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'count_value'

# %%
datagroupbyID.head(1000)
# Out:
#        VisitDate        UniqueVisitID                 VisitorGroup  \
# 0       7/1/2017     2014237601010030  Prior Visitor with Purchase
# 1       7/1/2017     2909699474086000                  New Visitor
# 2       7/1/2017     2987400996435030                  New Visitor
# 3       7/1/2017     6875972920873110  Prior Visitor with Purchase
# 4       7/1/2017    11534913004844900                  New Visitor
# 5       7/1/2017    14652409111989100  Prior Visitor with Purchase
# 6       7/1/2017    14963817946934700                  New Visitor
# 7       7/1/2017    25989738567729000  Prior Visitor with Purchase
# 8       7/1/2017    29576725167987100                  New Visitor
# 9       7/1/2017    33737592140659800  Prior Visitor with Purchase
# 10      7/1/2017    37785119521218400                  New Visitor
# 11      7/1/2017    42981783392286700  Prior Visitor with Purchase
# 12      7/1/2017    43601232830137300                Prior Visitor
# ...

# %%
data.Gender.count()
# Out:
# 639596

# %% [markdown]
# ### Clicked Banner

# %% [markdown]
# #### clicked and buy

# %%
dataclickedbannerbuy = data.query('ClickedBanner == 1 & Purchased == 1')

# %%
dataclickedbannerbuy
# Out:
#        VisitDate        UniqueVisitID                 VisitorGroup  \
# 102     7/1/2017   450095063575678000  Prior Visitor with Purchase
# 458     7/1/2017  2183372437928820000  Prior Visitor with Purchase
# 1126    7/1/2017  5468558904853240000  Prior Visitor with Purchase
# 1889    7/1/2017  9024632423881370000  Prior Visitor with Purchase
# 2139    7/2/2017  1131803789679720000  Prior Visitor with Purchase
# 2712    7/2/2017  3694196254507910000  Prior Visitor with Purchase
# 2957    7/2/2017  4949391288599590000  Prior Visitor with Purchase
# 3653    7/2/2017  8257223781011300000  Prior Visitor with Purchase
# 4217    7/3/2017  1695471137602220000  Prior Visitor with Purchase
# 5520    7/3/2017  7681805380717230000  Prior Visitor with Purchase
# 5966    7/4/2017   475517403431868000  Prior Visitor with Purchase
# 6835    7/4/2017  4231700677292130000                Prior Visitor
# 7469    7/1/2017  1378361405704010000  Prior Visitor with Purchase
# ...

# %% [markdown]
# #### clicked and added to basket and buy

# %%
clickedandaddandbuy = data.query('ClickedBanner == 1 & Purchased == 1& AddedToBasket == 1')

# %%
clickedandaddandbuy
# Out:
#        VisitDate        UniqueVisitID                 VisitorGroup  \
# 102     7/1/2017   450095063575678000  Prior Visitor with Purchase
# 458     7/1/2017  2183372437928820000  Prior Visitor with Purchase
# 1126    7/1/2017  5468558904853240000  Prior Visitor with Purchase
# 1889    7/1/2017  9024632423881370000  Prior Visitor with Purchase
# 2139    7/2/2017  1131803789679720000  Prior Visitor with Purchase
# 2957    7/2/2017  4949391288599590000  Prior Visitor with Purchase
# 3653    7/2/2017  8257223781011300000  Prior Visitor with Purchase
# 4217    7/3/2017  1695471137602220000  Prior Visitor with Purchase
# 5520    7/3/2017  7681805380717230000  Prior Visitor with Purchase
# 5966    7/4/2017   475517403431868000  Prior Visitor with Purchase
# 6835    7/4/2017  4231700677292130000                Prior Visitor
# 7469    7/1/2017  1378361405704010000  Prior Visitor with Purchase
# 9046    7/1/2017  8801310247727780000  Prior Visitor with Purchase
# ...

# %% [markdown]
# ### Not clicked banner

# %%
datanotclickedbanner = data.query('ClickedBanner == 0 ')

# %%
datanotclickedbanner
# Out:
#        VisitDate        UniqueVisitID                 VisitorGroup  \
# 0       7/1/2017     2014237601010030  Prior Visitor with Purchase
# 1       7/1/2017     2909699474086000                  New Visitor
# 2       7/1/2017     2987400996435030                  New Visitor
# 3       7/1/2017     6875972920873110  Prior Visitor with Purchase
# 4       7/1/2017    11534913004844900                  New Visitor
# 5       7/1/2017    14652409111989100  Prior Visitor with Purchase
# 6       7/1/2017    14963817946934700                  New Visitor
# 7       7/1/2017    25989738567729000  Prior Visitor with Purchase
# 8       7/1/2017    29576725167987100                  New Visitor
# 9       7/1/2017    33737592140659800  Prior Visitor with Purchase
# 10      7/1/2017    37785119521218400                  New Visitor
# 11      7/1/2017    42981783392286700  Prior Visitor with Purchase
# 12      7/1/2017    43601232830137300                Prior Visitor
# ...
